# %%
from tensorflow.keras.layers import Input, Dense, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras import metrics
from tensorflow.keras.datasets import mnist
import numpy as np

batch_size = 100
original_dim = 784
latent_dim = 2
intermediate_dim = 256
epochs = 50
epsilon_std = 1.0

def sampling(args: tuple):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim), mean=0, stddev=epsilon_std)
    return z_mean + K.exp(z_log_var / 2) * epsilon

x = Input(shape=(original_dim,), name="input")
h = Dense(intermediate_dim, activation="relu", name="encoding")(x)
z_mean = Dense(latent_dim, name="mean")(h)
z_log_var = Dense(latent_dim, name="log_variance")(h)
z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_var])
encoder = Model(x, [z_mean, z_log_var, z], name='encoder')

input_decoder = Input(shape=(latent_dim,), name="decoder_input")
decoder_h = Dense(intermediate_dim, activation="relu", name="decoder_h")(input_decoder)
x_decoded = Dense(original_dim, activation="sigmoid", name="flat_decoded")(decoder_h)
decoder = Model(input_decoder, x_decoded, name="decoder")

output_combined = decoder(encoder(x)[2])
vae = Model(x, output_combined)
vae.summary()

kl_loss = -0.5 * K.sum(1 + z_log_var - K.exp(z_log_var) - K.square(z_mean), axis=-1)
vae.add_loss(K.mean(kl_loss) / 784)
vae.compile(optimizer="rmsprop", loss="binary_crossentropy")

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

vae.fit(x_train, x_train, shuffle=True, epochs=epochs, batch_size=batch_size)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 784)]             0
#
#  encoder (Functional)        [(None, 2),               201988
#                               (None, 2),
#                               (None, 2)]
#
#  decoder (Functional)        (None, 784)               202256
#
# =================================================================
# Total params: 404,244
# Trainable params: 404,244
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2022-08-26 15:31:38.733270: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2459
# Epoch 2/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2180
# Epoch 3/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2134
# Epoch 4/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2108
# Epoch 5/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2089
# Epoch 6/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2075
# Epoch 7/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2064
# Epoch 8/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2054
# Epoch 9/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2045
# Epoch 10/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2037
# Epoch 11/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2030
# Epoch 12/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2023
# Epoch 13/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2017
# Epoch 14/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2011
# Epoch 15/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2006
# Epoch 16/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2001
# Epoch 17/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1997
# Epoch 18/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1992
# Epoch 19/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1989
# Epoch 20/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1984
# Epoch 21/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1981
# Epoch 22/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1977
# Epoch 23/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1974
# Epoch 24/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1972
# Epoch 25/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1968
# Epoch 26/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1966
# Epoch 27/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1963
# Epoch 28/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1961
# Epoch 29/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1958
# Epoch 30/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1956
# Epoch 31/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1953
# Epoch 32/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1951
# Epoch 33/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1949
# Epoch 34/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1947
# Epoch 35/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1945
# Epoch 36/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1943
# Epoch 37/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1941
# Epoch 38/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1940
# Epoch 39/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1938
# Epoch 40/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1936
# Epoch 41/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1935
# Epoch 42/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1933
# Epoch 43/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1931
# Epoch 44/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1930
# Epoch 45/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1929
# Epoch 46/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1927
# Epoch 47/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1926
# Epoch 48/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1924
# Epoch 49/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1923
# Epoch 50/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1922
